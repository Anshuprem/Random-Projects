# %%
pip install accelerate diffusers controlnet_aux
# Out:
# ...
#
#   Using cached accelerate-1.6.0-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached diffusers-0.32.2-py3-none-any.whl.metadata (18 kB)
# ...
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.2 MB 2.4 MB/s eta 0:00:02
#    ------------- -------------------------- 1.0/3.2 MB 2.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.6/3.2 MB 2.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.8/3.2 MB 2.0 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.2 MB 1.9 MB/s eta 0:00:01
#    -------------------------------- ------- 2.6/3.2 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.4 MB 2.5 MB/s eta 0:00:16
# ...

# %%
import torch

# %%
from controlnet_aux import CannyDetector
from diffusers import StableDiffusionXLAdapterPipeline , ControlNetModel
from diffusers.utils import load_image, make_image_grid

# %%
pip install torch torchvision torchaudio diffusers transformers safetensors
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.4 MB 1.7 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.4 MB 1.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.4 MB 1.6 MB/s eta 0:00:01
#    --------------------- ------------------ 1.3/2.4 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.4 MB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.4 MB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.4 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.2 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/10.2 MB 2.5 MB/s eta 0:00:04
# ...

# %%
pip install transformers
# Out:
# ...
#
# ...

# %%
pip install torch torchvision torchaudio diffusers transformers safetensors pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
